# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = read("/Users/varunsingh/Desktop/Projects/ResolveIQ/ResolveIQ/docs/exploration/data/complaints.csv", low_memory=False)
print("Hellow World")
print(f"Shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
